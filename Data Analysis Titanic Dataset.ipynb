# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import style
# %matplotlib  inline

# %%
df=pd.read_csv("C:\\Users\\91998\Desktop\\train.csv")

# %% [markdown]
# # Display Top 5 Rows

# %%
df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# # Check the last three rows of dataset

# %%
df.tail(3)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.shape
# Out:
# (891, 12)

# %%
df.size
# Out:
# 10692

# %%
df.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked
# 0      0  A/5 21171  7.25   NaN        S

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# # Survived(0=No,1=Yes)
# # Passenger Class - Pclass(1=1st Class, 2=2nd class,3=3rd Class)
# # name - Name
# # SibSp(Number of sibling /Spouses)
# # Parch(Number of parents/Children)
# # Ticket(Ticket Number)
# # Fare - Passenger Fare
# # Cabin - Cabin
# # Embarked-Port Of Embarkation(C=Cherbourg,Q=Queenstown,S=Southampton)

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.isnull().sum()*100/len(df)
# Out:
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            19.865320
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.000000
# Cabin          77.104377
# Embarked        0.224467
# dtype: float64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# # So as we can see 'Age' and 'Cabin' column containing null values so we have to clean it

# %%
df.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked
# 0      0  A/5 21171  7.25   NaN        S

# %% [markdown]
# # Cabin containing null values greater than 20 to 30 % so we have to drop it but we will not drop age column

# %%
df.drop(columns=['Cabin'],inplace=True)

# %%
df.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Embarked
# 0      0  A/5 21171  7.25        S

# %%
df.dropna(inplace=True)

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# # So we have dropped cabin column from dataset and clean age column now as we can see our dataset is cleaned now

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 712 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  712 non-null    int64
#  1   Survived     712 non-null    int64
#  2   Pclass       712 non-null    int64
#  3   Name         712 non-null    object
#  4   Sex          712 non-null    object
#  5   Age          712 non-null    float64
#  6   SibSp        712 non-null    int64
#  7   Parch        712 non-null    int64
#  8   Ticket       712 non-null    object
#  9   Fare         712 non-null    float64
#  10  Embarked     712 non-null    object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 66.8+ KB

# %% [markdown]
# # Check for duplicated values and drop it if exist

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Embarked]
# Index: []

# %% [markdown]
# # So no duplicate exist here

# %%
df.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Embarked
# 0      0  A/5 21171  7.25        S

# %%
sns.countplot(x='Survived',data=df)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
style.use('ggplot')
sns.pairplot(hue='Survived',data=df)

# %%
sns.boxplot(x='Age',data=df)
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
sns.boxplot(x='Fare',data=df)
# Out:
# <AxesSubplot:xlabel='Fare'>

# %% [markdown]
# # Who paid the most expensive ticket

# %%
df.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Embarked
# 0      0  A/5 21171  7.25        S

# %%
df.groupby(['PassengerId','Name']).Fare.max().sort_values(ascending=False).head(10)
# Out:
# PassengerId  Name
# 738          Lesurer, Mr. Gustave J                             512.3292
# 680          Cardeza, Mr. Thomas Drake Martinez                 512.3292
# 259          Ward, Miss. Anna                                   512.3292
# 28           Fortune, Mr. Charles Alexander                     263.0000
# 439          Fortune, Mr. Mark                                  263.0000
# 342          Fortune, Miss. Alice Elizabeth                     263.0000
# 89           Fortune, Miss. Mabel Helen                         263.0000
# 312          Ryerson, Miss. Emily Borie                         262.3750
# 743          Ryerson, Miss. Susan Parker "Suzette"              262.3750
# 300          Baxter, Mrs. James (Helene DeLaudeniere Chaput)    247.5208
# Name: Fare, dtype: float64

# %% [markdown]
# # What is the median age for all male passengers in the 3rd class

# %%
df.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Embarked
# 0      0  A/5 21171  7.25        S

# %%
ma=df[(df['Sex']=='male')&(df['Pclass']==3)]

# %%
ma['Age'].median()
# Out:
# 25.0

# %%
ma
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# 12            13         0       3  Saundercock, Mr. William Henry  male
# 13            14         0       3     Andersson, Mr. Anders Johan  male
# ..           ...       ...     ...                             ...   ...
# 876          877         0       3   Gustafsson, Mr. Alfred Ossian  male
# 877          878         0       3            Petroff, Mr. Nedelio  male
# 881          882         0       3              Markun, Mr. Johann  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch           Ticket     Fare Embarked
# ...

# %%
# The two

# %%
df.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Embarked
# 0      0  A/5 21171  7.25        S

# %%
df.groupby(['Survived','Sex']).Age.mean().unstack()
# Out:
# Sex          female       male
# Survived
# 0         25.046875  31.618056
# 1         28.630769  27.276022

# %%
df.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Embarked
# 0      0  A/5 21171  7.25        S

# %%
df['Fare'].var()
# Out:
# 2802.5004705658207

# %% [markdown]
# # How many People Survived and how many Died?

# %%
df.groupby('Survived').nunique()
# Out:
#           PassengerId  Survived  Pclass  Name  Sex  Age  SibSp  Parch  Ticket  \
# Survived
# 0                 424         1       3   424    2   77      6      7     364
# 1                 288         1       3   288    2   65      5      5     220
#
#           Fare  Embarked
# Survived
# 0          151         3
# 1          139         3

# %%
s=df[df['Survived']==0]
s.groupby('Survived').PassengerId.count()
# Out:
# Survived
# 0    424
# Name: PassengerId, dtype: int64

# %%
s=df[df['Survived']==1]
s.groupby('Survived').PassengerId.count()
# Out:
# Survived
# 1    288
# Name: PassengerId, dtype: int64

# %%
df.groupby('Survived').PassengerId.count()
# Out:
# Survived
# 0    424
# 1    288
# Name: PassengerId, dtype: int64

# %%
df.groupby('Survived').PassengerId.count().plot(kind='bar',color='red')
# Out:
# <AxesSubplot:xlabel='Survived'>

# %% [markdown]
# # So there are many method to do it

# %% [markdown]
# # How many passengers are there are in first class, second class , third class

# %%
df.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Embarked
# 0      0  A/5 21171  7.25        S

# %%
df.groupby('Pclass').PassengerId.count()
# Out:
# Pclass
# 1    184
# 2    173
# 3    355
# Name: PassengerId, dtype: int64

# %%
df.groupby('Pclass').PassengerId.count().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Pclass'>

# %%
# Number of male and female passengers

# %%
df.groupby('Sex').PassengerId.count()
# Out:
# Sex
# female    259
# male      453
# Name: PassengerId, dtype: int64

# %%
df.groupby('Sex').PassengerId.count().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='PassengerId'>

# %% [markdown]
# # Who has better chance of survival Male or Female

# %%
sns.barplot(y='Survived',x='Sex',data=df)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Survived'>

# %% [markdown]
# # So we can say that male has lesser chance to survival

# %% [markdown]
# # Which passenger class has better chance of survival(1st,2nd,3rd)

# %%
df.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Embarked
# 0      0  A/5 21171  7.25        S

# %%
sns.barplot(y='Survived',x='Pclass',data=df)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Survived'>

# %% [markdown]
# # We can say that pclass 1 means rich person has more chances of survival

# %% [markdown]
# # Create a new column called family_size using Sibsp and parch col

# %%
df['Family_Size'] = df['SibSp']+df['Parch']

# %%
df.head(4)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
#
#    Parch            Ticket     Fare Embarked  Family_Size
# 0      0         A/5 21171   7.2500        S            1
# 1      0          PC 17599  71.2833        C            1
# 2      0  STON/O2. 3101282   7.9250        S            0
# 3      0            113803  53.1000        S            1

# %% [markdown]
# # Find Fare Per Person

# %%
df['Fare Per Person']=df['Fare']/df['Family_Size']

# %%
df.head(4)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
#
#    Parch            Ticket     Fare Embarked  Family_Size  Fare Per Person
# 0      0         A/5 21171   7.2500        S            1           7.2500
# 1      0          PC 17599  71.2833        C            1          71.2833
# 2      0  STON/O2. 3101282   7.9250        S            0              inf
# 3      0            113803  53.1000        S            1          53.1000

# %% [markdown]
# # there are several family group (with more than 6 family members) on board who are they

# %%
df[df['Family_Size']>6]
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 59            60         0       3       Goodwin, Master. William Frederick
# 71            72         0       3               Goodwin, Miss. Lillian Amy
# 386          387         0       3          Goodwin, Master. Sidney Leonard
# 480          481         0       3           Goodwin, Master. Harold Victor
# 678          679         0       3  Goodwin, Mrs. Frederick (Augusta Tyler)
# 683          684         0       3              Goodwin, Mr. Charles Edward
#
#         Sex   Age  SibSp  Parch   Ticket  Fare Embarked  Family_Size  \
# 59     male  11.0      5      2  CA 2144  46.9        S            7
# 71   female  16.0      5      2  CA 2144  46.9        S            7
# 386    male   1.0      5      2  CA 2144  46.9        S            7
# 480    male   9.0      5      2  CA 2144  46.9        S            7
# 678  female  43.0      1      6  CA 2144  46.9        S            7
# ...
